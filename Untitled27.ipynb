# %% [markdown]
# <a href="https://colab.research.google.com/github/pradiptars/DataScience_LinearLassoRidgeRegression/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-473c37ed-8287-4de5-aa2c-e9b5ee97304d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-473c37ed-8287-4de5-aa2c-e9b5ee97304d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Home.csv')
df
# Out:
#      bath   balcony  price      total   squrft  bhk   priceprersquri
# 0       12       10     150      18000     167     5           89655
# 1       13       11     151      21593     167     5           89655
# 2       14       12     152      25536     167     5           89655
# 3       15       13     153      29835     167     5           89655
# 4       16       14     154      34496     167     5           89655
# ..     ...      ...     ...        ...     ...   ...             ...
# 470    482      480     620  143443200     167     5           89655
# 471    483      481     621  144272583     167     5           89655
# 472    484      482     622  145105136     167     5           89655
# 473    485      483     623  145940865     167     5           89655
# 474    486      484     624  146779776     167     5           89655
#
# [475 rows x 7 columns]

# %%
X = df.drop('price ', axis=1)
y = df['price ']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=51)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (380, 6) (95, 6) (380,) (95,)

# %%
X_train
# Out:
#      bath   balcony     total   squrft  bhk   priceprersquri
# 30      42       40     302400     167     5           89655
# 365    377      375   72808125     167     5           89655
# 111    123      121    3884463     167     5           89655
# 61      73       71    1093613     167     5           89655
# 416    428      426  103197648     167     5           89655
# ..     ...      ...        ...     ...   ...             ...
# 16      28       26     120848     167     5           89655
# 197    209      207   15012261     167     5           89655
# 457    469      467  132946961     167     5           89655
# 224    236      234   20653776     167     5           89655
# 57      69       67     956961     167     5           89655
#
# [380 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_sc = sc.transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train_sc, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 6.88403083e+01,  6.88403083e+01, -1.42108547e-14,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])

# %%
lr.intercept_
# Out:
# 381.05526315789473

# %% [markdown]
# Pradict the value

# %%
X_test[0 : ]
# Out:
#      bath   balcony     total   squrft  bhk   priceprersquri
# 358    370      368   69169280     167     5           89655
# 188    200      198   13384800     167     5           89655
# 306    318      316   45822528     167     5           89655
# 470    482      480  143443200     167     5           89655
# 291    303      301   40220523     167     5           89655
# ..     ...      ...        ...     ...   ...             ...
# 94     106      104    2689856     167     5           89655
# 199    211      209   15390551     167     5           89655
# 324    336      334   53194176     167     5           89655
# 44      56       54     586656     167     5           89655
# 137    149      147    6286161     167     5           89655
#
# [95 rows x 6 columns]

# %%
lr.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([51185.20281677, 27779.49798211, 44025.81074979, 66605.43188377,
#        41960.60149968, 57931.55303364,  5062.19623024, 17315.77111463,
#        39482.35039954, 51735.92528346, 31496.87463237, 37417.14114942,
#        62750.37461707, 63851.81955042, 37004.0992994 , 67018.47373378,
#         9605.65658065, 28330.22044882, 47330.14554994, 31772.23586572,
#        10018.69843068, 44851.89444983, 45953.33938321, 47880.86801663,
#        63714.13893375, 49670.71603338, 57518.51118363, 48018.54863331,
#        30946.15216567, 29431.66538223, 25301.24688193, 20069.38344819,
#        24199.80194851, 51047.5222001 , 28054.85921546,  2859.30636338,
#        33011.36141581, 52699.68960016, 35627.29313264, 16489.68741456,
#        59721.40105035, 55177.94070024, 29982.38784893, 47467.82616662,
# ...

# %%
lr.predict(X_test[0 :])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([51185.20281677, 27779.49798211, 44025.81074979, 66605.43188377,
#        41960.60149968, 57931.55303364,  5062.19623024, 17315.77111463,
#        39482.35039954, 51735.92528346, 31496.87463237, 37417.14114942,
#        62750.37461707, 63851.81955042, 37004.0992994 , 67018.47373378,
#         9605.65658065, 28330.22044882, 47330.14554994, 31772.23586572,
#        10018.69843068, 44851.89444983, 45953.33938321, 47880.86801663,
#        63714.13893375, 49670.71603338, 57518.51118363, 48018.54863331,
#        30946.15216567, 29431.66538223, 25301.24688193, 20069.38344819,
#        24199.80194851, 51047.5222001 , 28054.85921546,  2859.30636338,
#        33011.36141581, 52699.68960016, 35627.29313264, 16489.68741456,
#        59721.40105035, 55177.94070024, 29982.38784893, 47467.82616662,
# ...

# %%
y_test
# Out:
# 358    508
# 188    338
# 306    456
# 470    620
# 291    441
#       ...
# 94     244
# 199    349
# 324    474
# 44     194
# 137    287
# Name: price , Length: 95, dtype: int64

# %%
lr.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -98656.76707601009

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
ridge.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.50123e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 0.9999999999999586

# %%
ls = Lasso()
ls.fit(X_train, y_train)
ls.score(X_test, y_test)
# Out:
# 0.9999999986722486

# %%
ridge2 = Ridge(alpha=2)
ridge2.fit(X_train, y_train)
ridge2.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=3.00247e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 0.9999999999998344

# %%
ls2 = Lasso(alpha=2)
ls2.fit(X_train, y_train)
ls2.score(X_test, y_test)
# Out:
# 0.9999999946889946
